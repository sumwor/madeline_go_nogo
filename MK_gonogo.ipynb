# %% [markdown]
# Jupyter notebook for data analysis

# %% [markdown]
# # 1. Prepare behavior data for later process

# %% [markdown]
# ## 1.1 Preprocessing of behavior files in Matlab

# %% [markdown]
# ## 1.2 Go over every behavior session

# %%
# %matplotlib inline
import pickle

import numpy as np
import pandas as pd

root_dir = {}

# 4 groups in total: 
# 1. animals learnt the task at late learning stage (experts)
# 2. animals learnt the task at early learning stage (to-be experts)
# 3. animals that failed in the end at early learning stage
# 4. animals that failed in the end at late learning stage
root_dir['LateLearnt'] = r'Z:\HongliWang\Madeline\LateLearning'
root_dir['EarlyLearnt'] = r'Z:\HongliWang\Madeline\EarlyLearning'
root_dir['LateUneducated'] = r'Z:\HongliWang\Madeline\Nonlearning_Late'
root_dir['EarlyUneducated'] = r'Z:\HongliWang\Madeline\Nonlearning_Early'

keyList = root_dir.keys()

# %%
# process the behavioral data
from behavioral_pipeline import *
for key in root_dir.keys():
    beh_sum = GoNogoBehaviorSum(root_dir[key])
    #matplotlib.use('Agg')
    beh_sum.process_singleSession(ifrun=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 # process the behavioral data
# ----> 2 from behavioral_pipeline import *
#       3 for key in root_dir.keys():
#       4     beh_sum = GoNogoBehaviorSum(root_dir[key])
#
# File ~\Documents\GitHub\madeline_go_nogo\behavioral_pipeline.py:24
#      22 import time
#      23 from statsmodels.stats.multicomp import MultiComparison
# ---> 24 import pingouin as pg
#      26 import pandas as pd
#      27 import pickle
#
# File ~\miniconda3\lib\site-packages\pingouin\__init__.py:7
#       5 from .distribution import *
#       6 from .effsize import *
# ----> 7 from .equivalence import *
#       8 from .multicomp import *
#       9 from .multivariate import *
#
# File ~\miniconda3\lib\site-packages\pingouin\equivalence.py:5
#       3 import numpy as np
#       4 import pandas as pd
# ----> 5 from pingouin.parametric import ttest
#       6 from pingouin.utils import _postprocess_dataframe
#       9 __all__ = ["tost"]
#
# File ~\miniconda3\lib\site-packages\pingouin\parametric.py:7
#       5 import pandas as pd
#       6 from scipy.stats import f
# ----> 7 import pandas_flavor as pf
#       8 from pingouin import (
#       9     _check_dataframe,
#      10     remove_na,
#    (...)
#      15     _postprocess_dataframe,
#      16 )
#      18 __all__ = ["ttest", "rm_anova", "anova", "welch_anova", "mixed_anova", "ancova"]
#
# File ~\miniconda3\lib\site-packages\pandas_flavor\__init__.py:5
#       1 from .register import (register_series_method,
#       2                        register_series_accessor,
#       3                        register_dataframe_method,
#       4                        register_dataframe_accessor)
# ----> 5 from .xarray import (register_xarray_dataarray_method,
#       6                      register_xarray_dataset_method)
#
# File ~\miniconda3\lib\site-packages\pandas_flavor\xarray.py:2
# ----> 2 import xarray as xr
#       4 from xarray import register_dataarray_accessor, register_dataset_accessor
#       5 from functools import wraps
#
# File ~\miniconda3\lib\site-packages\xarray\__init__.py:1
# ----> 1 from xarray import testing, tutorial
#       2 from xarray.backends.api import (
#       3     load_dataarray,
#       4     load_dataset,
#    (...)
#       8     save_mfdataset,
#       9 )
#      10 from xarray.backends.zarr import open_zarr
#
# File ~\miniconda3\lib\site-packages\xarray\tutorial.py:16
#      12 from typing import TYPE_CHECKING
#      14 import numpy as np
# ---> 16 from xarray.backends.api import open_dataset as _open_dataset
#      17 from xarray.core.dataarray import DataArray
#      18 from xarray.core.dataset import Dataset
#
# File ~\miniconda3\lib\site-packages\xarray\backends\__init__.py:7
#       1 """Backend objects for saving and loading data
#       2
#       3 DataStores provide a uniform interface for saving and loading data in different
#       4 formats. They should not be used directly, but rather through Dataset objects.
#       5 """
#       6 from xarray.backends.common import AbstractDataStore, BackendArray, BackendEntrypoint
# ----> 7 from xarray.backends.file_manager import (
#       8     CachingFileManager,
#       9     DummyFileManager,
#      10     FileManager,
#      11 )
#      12 from xarray.backends.h5netcdf_ import H5netcdfBackendEntrypoint, H5NetCDFStore
#      13 from xarray.backends.memory import InMemoryDataStore
#
# File ~\miniconda3\lib\site-packages\xarray\backends\file_manager.py:12
#       9 from collections.abc import Hashable
#      10 from typing import Any
# ---> 12 from xarray.backends.locks import acquire
#      13 from xarray.backends.lru_cache import LRUCache
#      14 from xarray.core import utils
#
# File ~\miniconda3\lib\site-packages\xarray\backends\locks.py:10
#       7 from typing import Any
#       9 try:
# ---> 10     from dask.utils import SerializableLock
#      11 except ImportError:
#      12     # no need to worry about serializing the lock
#      13     SerializableLock = threading.Lock  # type: ignore
#
# File ~\miniconda3\lib\site-packages\dask\__init__.py:3
#       1 from dask import config, datasets
#       2 from dask._version import get_versions
# ----> 3 from dask.base import (
#       4     annotate,
#       5     compute,
#       6     is_dask_collection,
#       7     optimize,
#       8     persist,
#       9     visualize,
#      10 )
#      11 from dask.core import istask
#      12 from dask.delayed import delayed
#
# File ~\miniconda3\lib\site-packages\dask\base.py:33
#      31 from dask.core import get as simple_get
#      32 from dask.core import literal, quote
# ---> 33 from dask.hashing import hash_buffer_hex
#      34 from dask.system import CPU_COUNT
#      35 from dask.typing import SchedulerGetCallable
#
# File ~\miniconda3\lib\site-packages\dask\hashing.py:33
#      30         hashers.append(_hash_cityhash)
#      32 try:
# ---> 33     import xxhash  # `python -m pip install xxhash`
#      34 except ImportError:
#      35     pass
#
# File <frozen importlib._bootstrap>:1007, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:982, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:925, in _find_spec(name, path, target)
#
# File <frozen importlib._bootstrap_external>:1423, in find_spec(cls, fullname, path, target)
#
# File <frozen importlib._bootstrap_external>:1395, in _get_spec(cls, fullname, path, target)
#
# File <frozen importlib._bootstrap_external>:1550, in find_spec(self, fullname, target)
#
# File <frozen importlib._bootstrap_external>:99, in _path_join(*path_parts)
#
# KeyboardInterrupt:

# %% [markdown]
# # 2. Preprocessing of fluorescent data

# %% [markdown]
# ## 2.1 calculate dF/F, read sessions into dataframe for later analysis

# %% [markdown]
# ### Experts in late learning stage

# %%
# initialize session list
from fluorescent_pipeline import *

# %%
fluo_summary = {}
ADT = {}
JUV = {}
group_label = {}

# %%
key = "LateLearnt"
fluo_summary[key] = fluoSum(root_dir[key])
fluo_summary[key].process_single_session()

# optional: plot PSTH for every neuron
#fluo_summary.cell_plots()

# set the adolescents and adults groups        
for ii in range(len(fluo_summary[key].data_df['age'])):
    if fluo_summary[key].data_df['age'][ii] == 'TRA':
        fluo_summary[key].data_df['age'][ii] = 'ADT'

c2 = np.logical_and(fluo_summary[key].data_df['age'] == 'ADT', fluo_summary[key].data_df['with_imaging'])
c3 = np.logical_and(fluo_summary[key].data_df['age'] == 'JUV',fluo_summary[key].data_df['with_imaging'])

ADT[key] = fluo_summary[key].data_df[c2]
JUV[key] = fluo_summary[key].data_df[c3]
group_label[key] = key
# Out:
#  15%|█▌        | 11/71 [00:42<04:27,  4.47s/it]
# Warning! Duplicate timestamps(4.0, 44.0)at time 4309.936876 in <behavioral_pipeline.GoNogoBehaviorMat object at 0x0000024EF38374C0>
#  21%|██        | 15/71 [00:49<02:21,  2.53s/it]
# Warning! Duplicate timestamps(4.0, 44.0)at time 16.211313 in <behavioral_pipeline.GoNogoBehaviorMat object at 0x0000024EA891EBE0>
# Warning! Duplicate timestamps(4.0, 44.0)at time 380.356064 in <behavioral_pipeline.GoNogoBehaviorMat object at 0x0000024E40F4F040>
#  30%|██▉       | 21/71 [00:51<00:43,  1.16it/s]
# Warning! Duplicate timestamps(4.0, 6.0)at time 227.76413 in <behavioral_pipeline.GoNogoBehaviorMat object at 0x0000024E466A8D00>
# Warning! Duplicate timestamps(4.0, 66.0)at time 229.43179 in <behavioral_pipeline.GoNogoBehaviorMat object at 0x0000024E466A8D00>
#  49%|████▉     | 35/71 [01:15<00:32,  1.09it/s]
# Warning! Duplicate timestamps(3.0, 5.0)at time 4121.263388 in <behavioral_pipeline.GoNogoBehaviorMat object at 0x0000024F9146ADF0>
# Warning! Duplicate timestamps(3.0, 5.0)at time 4122.629549 in <behavioral_pipeline.GoNogoBehaviorMat object at 0x0000024F9146ADF0>
# Warning! Duplicate timestamps(3.0, 5.0)at time 4437.285631 in <behavioral_pipeline.GoNogoBehaviorMat object at 0x0000024F9146ADF0>
# Warning! Duplicate timestamps(3.0, 5.0)at time 4710.790197 in <behavioral_pipeline.GoNogoBehaviorMat object at 0x0000024F9146ADF0>
# Warning! Duplicate timestamps(4.0, 6.0)at time 4710.830864 in <behavioral_pipeline.GoNogoBehaviorMat object at 0x0000024F9146ADF0>
# Warning! Duplicate timestamps(3.0, 5.0)at time 4711.304861 in <behavioral_pipeline.GoNogoBehaviorMat object at 0x0000024F9146ADF0>
# Warning! Duplicate timestamps(4.0, 6.0)at time 5205.533051 in <behavioral_pipeline.GoNogoBehaviorMat object at 0x0000024F9146ADF0>
# Warning! Duplicate timestamps(3.0, 5.0)at time 5206.778713 in <behavioral_pipeline.GoNogoBehaviorMat object at 0x0000024F9146ADF0>
# Warning! Duplicate timestamps(4.0, 6.0)at time 5208.524539 in <behavioral_pipeline.GoNogoBehaviorMat object at 0x0000024F9146ADF0>
# Warning! Duplicate timestamps(3.0, 5.0)at time 1266.656691 in <behavioral_pipeline.GoNogoBehaviorMat object at 0x0000024FA3615B80>
#  59%|█████▉    | 42/71 [01:15<00:10,  2.79it/s]
# Warning! Duplicate timestamps(4.0, 44.0)at time 991.368309 in <behavioral_pipeline.GoNogoBehaviorMat object at 0x0000024FA458C7C0>
# 100%|██████████| 71/71 [04:42<00:00,  3.98s/it]

# %% [markdown]
# ### Experts in early learning stage

# %%
key = "EarlyLearnt"
fluo_summary[key] = fluoSum(root_dir[key])
fluo_summary[key].process_single_session()

# optional: plot PSTH for every neuron
#fluo_summary.cell_plots()

# set the adolescents and adults groups        
for ii in range(len(fluo_summary[key].data_df['age'])):
    if fluo_summary[key].data_df['age'][ii] == 'TRA':
        fluo_summary[key].data_df['age'][ii] = 'ADT'

c2 = np.logical_and(fluo_summary[key].data_df['age'] == 'ADT', fluo_summary.data_df['with_imaging'])
c3 = np.logical_and(fluo_summary[key].data_df['age'] == 'JUV',fluo_summary.data_df['with_imaging'])

ADT[key] = fluo_summary[key].data_df[c2]
JUV[key] = fluo_summary[key].data_df[c3]
group_label[key] = key

# %% [markdown]
# ### non-learners in late stage

# %%
key = "LateUneducated"
fluo_summary[key] = fluoSum(root_dir[key])
fluo_summary[key].process_single_session()

# optional: plot PSTH for every neuron
#fluo_summary.cell_plots()

# set the adolescents and adults groups        
for ii in range(len(fluo_summary[key].data_df['age'])):
    if fluo_summary[key].data_df['age'][ii] == 'TRA':
        fluo_summary[key].data_df['age'][ii] = 'ADT'

c2 = np.logical_and(fluo_summary[key].data_df['age'] == 'ADT', fluo_summary.data_df['with_imaging'])
c3 = np.logical_and(fluo_summary[key].data_df['age'] == 'JUV',fluo_summary.data_df['with_imaging'])

ADT[key] = fluo_summary[key].data_df[c2]
JUV[key] = fluo_summary[key].data_df[c3]
group_label[key] = key

# %% [markdown]
# ### non-learners in early stage

# %%
key = "EarlyUneducated"
fluo_summary[key] = fluoSum(root_dir[key])
fluo_summary[key].process_single_session()

# optional: plot PSTH for every neuron
#fluo_summary.cell_plots()

# set the adolescents and adults groups        
for ii in range(len(fluo_summary[key].data_df['age'])):
    if fluo_summary[key].data_df['age'][ii] == 'TRA':
        fluo_summary[key].data_df['age'][ii] = 'ADT'

c2 = np.logical_and(fluo_summary[key].data_df['age'] == 'ADT', fluo_summary.data_df['with_imaging'])
c3 = np.logical_and(fluo_summary[key].data_df['age'] == 'JUV',fluo_summary.data_df['with_imaging'])

ADT[key] = fluo_summary[key].data_df[c2]
JUV[key] = fluo_summary[key].data_df[c3]
group_label[key] = key

# %% [markdown]
# ## 2.2 Multiple linear regression - determine the effect of running on dF/F

# %%
# multiple linear regression for each session
key='LateLearnt'
fluo_summary[key].MLR_session()

# %%
# %matplotlib inline
#fluo_summary[key].MLR_session()

key = "LateLearnt"
fluo_summary[key].MLR_summary(ADT[key], JUV[key], group_label[key])
# Out:
# 100%|██████████| 12/12 [00:00<00:00, 34.08it/s]
# 100%|██████████| 28/28 [00:00<00:00, 29.77it/s]

# %%
# comparison of latelearnt and early learnt group
#stats across early and late learning stage
import os
from scipy.stats import wilcoxon, mannwhitneyu
from statsmodels.stats.multitest import multipletests
from scipy.stats import median_abs_deviation

LateRunningPath = os.path.join(root_dir['LateLearnt'], r'Summary\fluo\RunningVariance_session.pickle')
EarlyRunningPath = os.path.join(root_dir['EarlyLearnt'], r'Summary\fluo\RunningVariance_session.pickle')

with open(LateRunningPath,"rb") as pickle_file:
    # Load the data from the pickle file
    latevar = pickle.load(pickle_file)
    
with open(EarlyRunningPath,"rb") as pickle_file:
    # Load the data from the pickle file
    earlyvar = pickle.load(pickle_file)

stats, p_learningJUV1 = mannwhitneyu(earlyvar['aveRunningSesJUV1'], latevar['aveRunningSesJUV1'])
stats, p_learningJUV2 = mannwhitneyu(earlyvar['aveRunningSesJUV2'], latevar['aveRunningSesJUV2'])
stats, p_learningADT1 = mannwhitneyu(earlyvar['aveRunningSesADT1'], latevar['aveRunningSesADT1'])
stats, p_learningADT2 = mannwhitneyu(earlyvar['aveRunningSesADT2'], latevar['aveRunningSesADT2'])
p_list = np.array([p_learningJUV1, p_learningJUV2, p_learningADT1, p_learningADT2])
q_list = multipletests(p_list, method='fdr_bh')[1]

print("Median of ADT 1-2 s, early:", np.median(earlyvar['aveRunningSesADT2']))
print("MAD of ADT 1-2 s, early:", median_abs_deviation(earlyvar['aveRunningSesADT2']))
print ("Median of ADT 1-2 s, late:", np.median(latevar['aveRunningSesADT2']))
print("MAD of ADT 1-2 s, late:", median_abs_deviation(latevar['aveRunningSesADT2']))
print("Median of JUV 1-2 s, early:", np.median(earlyvar['aveRunningSesJUV2']))
print("MAD of JUV 1-2 s, early:", median_abs_deviation(earlyvar['aveRunningSesJUV2']))
print("Median of JUV 1-2 s, late:", np.median(latevar['aveRunningSesJUV2']))
print("MAD of JUV 1-2 s, late:", median_abs_deviation(latevar['aveRunningSesJUV2']))

stages = ['JUV 0-1s', 'JUV 1-2s', 'ADT 0-1s', 'ADT 1-2s']
for idx,stage in enumerate(stages):
    print("Learning stage" + stage + f" p-value {p_list[idx]:.8f}, adjusted p-value {p_list[idx]:.8f} ")
data = {'stats': ['JUV0-1', 'JUV1-2', 'ADT0-1', 'ADT1-2'],
        'p_values': p_list,
        'adj_p_values': q_list}
dataDF = pd.DataFrame(data)
SummaryFolder = os.path.join(root_dir['LateLearnt'], r'Summary/ComparisonXLearning')
if not os.path.exists(SummaryFolder):
    os.makedirs(SummaryFolder)
dataDF.to_csv(os.path.join(SummaryFolder, 'runningVariance_xlearning_session.csv'))
# Out:
# Median of ADT 1-2 s, early: 0.1910357037897954
# MAD of ADT 1-2 s, early: 0.040776619624337596
# Median of ADT 1-2 s, late: 0.2590789261605507
# MAD of ADT 1-2 s, late: 0.052092116600760546
# Median of JUV 1-2 s, early: 0.20348778798189704
# MAD of JUV 1-2 s, early: 0.04139290165622046
# Median of JUV 1-2 s, late: 0.12788614175762347
# MAD of JUV 1-2 s, late: 0.03577369638623333
# Learning stageJUV 0-1s p-value 0.00158053, adjusted p-value 0.00158053
# Learning stageJUV 1-2s p-value 0.00060838, adjusted p-value 0.00060838
# Learning stageADT 0-1s p-value 0.16611997, adjusted p-value 0.16611997
# Learning stageADT 1-2s p-value 0.10289828, adjusted p-value 0.10289828

# %% [markdown]
# ## Decoding analysis

# %%
# decoding analysis
classifier = 'SVC'
spec = ''  # vanilla decoding
n_predictors = 14
for key in keyList:
    fluo_summary[key]. decoding_session(n_predictors, classifier, spec)
 
spec = 'noRun'
fluo_summary['LateLearnt']. decoding_session(n_predictors, classifier, spec)

# %%
# compare decoding accuracy across learning for experts animals
# load the data
# %matplotlib inline
lateLearntFile = os.path.join(root_dir['LateLearnt'],'Summary','fluo','decoding_accuracy_1sWindow.pickle')
earlyLearntFile = os.path.join(root_dir['EarlyLearnt'],'Summary','fluo','decoding_accuracy_1sWindow.pickle')

lateUneducatedFile = os.path.join(root_dir['LateUneducated'],'Summary','fluo','decoding_accuracy_1sWindow_allSession.pickle')
earlyUneducatedFile = os.path.join(root_dir['EarlyUneducated'],'Summary','fluo','decoding_accuracy_1sWindow_allSession.pickle')

with open(lateUneducatedFile, 'rb') as f:
    lateUneducatedResult = pickle.load(f)
    f.close()
with open(earlyUneducatedFile, 'rb') as f:
    earlyUneducatedResult = pickle.load(f)
    f.close()
with open(lateLearntFile, 'rb') as f:
    lateLearntResult = pickle.load(f)
    f.close()
with open(earlyLearntFile, 'rb') as f:
    earlyLearntResult = pickle.load(f)
    f.close()
    
# compare early and late learnt for decoding accuracy
p_MWtest1 = mannwhitneyu(earlyLearntResult['ADT1'], lateLearntResult['ADT1'])[1]
p_MWtest2 = mannwhitneyu(earlyLearntResult['ADT2'], lateLearntResult['ADT2'])[1]
p_MWtest3 = mannwhitneyu(earlyLearntResult['JUV1'], lateLearntResult['JUV1'])[1]
p_MWtest4 = mannwhitneyu(earlyLearntResult['JUV2'], lateLearntResult['JUV2'])[1]
p_list = np.array([p_MWtest1, p_MWtest2, p_MWtest3, p_MWtest4])
q_list = multipletests(p_list, method = 'fdr_bh')[1]
groups = ['ADT 0-1s', 'ADT 1-2s', 'JUV 0-1s', 'JUV 1-2s']
print("Comparison between early and late learnt animals")
for idx,group in enumerate(groups):
    print("Decoding accuracy for "+group+ f" p-value: {p_list[idx]:.4e}, adjusted p-value: {q_list[idx]:.4e}")
print("=======================================================================\n") 
# compare non-learn with early learnt
combinedResult = {}
for key in lateLearntResult.keys():
    combinedResult[key] = np.concatenate((earlyUneducatedResult[key],lateUneducatedResult[key]))
p_MWtest1 = mannwhitneyu(earlyLearntResult['ADT1'], combinedResult['ADT1'])[1]
p_MWtest2 = mannwhitneyu(earlyLearntResult['ADT2'], combinedResult['ADT2'])[1]
p_MWtest3 = mannwhitneyu(earlyLearntResult['JUV1'], combinedResult['JUV1'])[1]
p_MWtest4 = mannwhitneyu(earlyLearntResult['JUV2'], combinedResult['JUV2'])[1]
p_list = np.array([p_MWtest1, p_MWtest2, p_MWtest3, p_MWtest4])
q_list = multipletests(p_list, method = 'fdr_bh')[1]
groups = ['ADT 0-1s', 'ADT 1-2s', 'JUV 0-1s', 'JUV 1-2s']
print("Comparison between non learns and early learnt animals")
for idx,group in enumerate(groups):
    print("Decoding accuracy for "+group+ f" p-value: {p_list[idx]:.4e}, adjusted p-value: {q_list[idx]:.4e}")
    
print("=======================================================================\n") 

p_MWtest1 = mannwhitneyu(lateLearntResult['ADT1'], combinedResult['ADT1'])[1]
p_MWtest2 = mannwhitneyu(lateLearntResult['ADT2'], combinedResult['ADT2'])[1]
p_MWtest3 = mannwhitneyu(lateLearntResult['JUV1'], combinedResult['JUV1'])[1]
p_MWtest4 = mannwhitneyu(lateLearntResult['JUV2'], combinedResult['JUV2'])[1]
p_list = np.array([p_MWtest1, p_MWtest2, p_MWtest3, p_MWtest4])
q_list = multipletests(p_list, method = 'fdr_bh')[1]
groups = ['ADT 0-1s', 'ADT 1-2s', 'JUV 0-1s', 'JUV 1-2s']
print("Comparison between non learns and late learnt animals")
for idx,group in enumerate(groups):
    print("Decoding accuracy for "+group+ f" p-value: {p_list[idx]:.4e}, adjusted p-value: {q_list[idx]:.4e}")
# Out:
# Comparison between early and late learnt animals
# Decoding accuracy for ADT 0-1s p-value: 9.5779e-01, adjusted p-value: 9.5779e-01
# Decoding accuracy for ADT 1-2s p-value: 5.6219e-01, adjusted p-value: 7.4958e-01
# Decoding accuracy for JUV 0-1s p-value: 6.6740e-02, adjusted p-value: 1.3348e-01
# Decoding accuracy for JUV 1-2s p-value: 2.1656e-03, adjusted p-value: 8.6626e-03
# =======================================================================
#
# Comparison between non learns and early learnt animals
# Decoding accuracy for ADT 0-1s p-value: 6.5338e-01, adjusted p-value: 6.8882e-01
# Decoding accuracy for ADT 1-2s p-value: 2.0567e-01, adjusted p-value: 4.1133e-01
# Decoding accuracy for JUV 0-1s p-value: 1.9687e-01, adjusted p-value: 4.1133e-01
# Decoding accuracy for JUV 1-2s p-value: 6.8882e-01, adjusted p-value: 6.8882e-01
# =======================================================================
#
# Comparison between non learns and late learnt animals
# Decoding accuracy for ADT 0-1s p-value: 8.6394e-01, adjusted p-value: 8.6394e-01
# Decoding accuracy for ADT 1-2s p-value: 2.2378e-01, adjusted p-value: 2.9837e-01
# Decoding accuracy for JUV 0-1s p-value: 7.6949e-03, adjusted p-value: 1.5390e-02
# Decoding accuracy for JUV 1-2s p-value: 2.3194e-04, adjusted p-value: 9.2774e-04

# %%
# now try no cap, all neurons included for every session
# %matplotlib inline
import os
from scipy.stats import wilcoxon, mannwhitneyu
from statsmodels.stats.multitest import multipletests
import pandas as pd
from scipy.stats import median_abs_deviation
from statsmodels.stats.anova import AnovaRM
from statsmodels.stats.multicomp import MultiComparison
from scipy import stats

lateUneducatedFile = os.path.join(root_dir['LateUneducated'],'Summary','fluo','decoding_accuracy_1sWindow_allSession.pickle')
earlyUneducatedFile = os.path.join(root_dir['EarlyUneducated'],'Summary','fluo','decoding_accuracy_1sWindow_allSession.pickle')
nIdx = 100

with open(lateUneducatedFile, 'rb') as f:
    lateResult = pickle.load(f)
    f.close()
with open(earlyUneducatedFile, 'rb') as f:
    earlyResult = pickle.load(f)
    f.close()
    
# combine the result
combinedResult = {}
for key in lateResult.keys():
    combinedResult[key] = np.concatenate((earlyResult[key],lateResult[key]))
    globals()[key] = combinedResult[key]
    
p_MWtest1 = mannwhitneyu(ADT1, JUV1)[1]
p_MWtest2 = mannwhitneyu(ADT2, JUV2)[1]
p_list = np.array([p_MWtest1, p_MWtest2])
q_list = multipletests(p_list, method = 'fdr_bh')[1]
print("Mannwhitney results between adults and adolescents in 0-1 and 1-2s time window:")
print(p_list)

# plot the combined result
stat,p_ctrlADT1 = wilcoxon(ADT1, ADT1_Ctrl)
stat,p_ctrlADT2 = wilcoxon(ADT2, ADT2_Ctrl)
stat,p_ctrlJUV1 = wilcoxon(JUV1, JUV1_Ctrl)
stat,p_ctrlJUV2 = wilcoxon(JUV2, JUV2_Ctrl)
p_list_ctrl = np.array([p_ctrlADT1, p_ctrlADT2, p_ctrlJUV1, p_ctrlJUV2])
q_list_ctrl = multipletests(p_list_ctrl, method = 'fdr_bh')[1]

# print the p values
groups = ['ADT 0-1s', 'ADT 1-2s', 'JUV 0-1s', 'JUV 1-2s']
for idx,group in enumerate(groups):
    print("Decoding accuracy for "+group+ f" p-value: {p_list_ctrl[idx]:.4e}, adjusted p-value: {q_list_ctrl[idx]:.4e}")
# save the pvalues
data = {'groups':['Age0-1', 'Age1-2', 'ADT0-1', 'ADT1-2','JUV0-1', 'JUV1-2'],
        'p_values': np.concatenate((p_list, p_list_ctrl)),
        'adj_p_values': np.concatenate((q_list, q_list_ctrl))}
dataDF = pd.DataFrame(data)
#dataDF.to_csv(os.path.join(saveFigPath, 'stats_for_aveDecoding_n='+str((nIdx+1)*10)+'.csv'))
print("Median of ADT 0-1s:", np.median(ADT1))
print("MAD of ADT 0-1s:", median_abs_deviation(ADT1))
print ("Median of ADT 1-2s:", np.median(ADT2))
print("MAD of ADT 1-2s:", median_abs_deviation(ADT2))
print("Median of JUV 0-1s:", np.median(JUV1))
print("MAD of JUV 0-1s:", median_abs_deviation(JUV1))
print("Median of JUV 1-2s:", np.median(JUV2))
print("MAD of JUV 1-2s:", median_abs_deviation(JUV2))

print("Median of ADT ctrl 0-1s:", np.median(ADT1_Ctrl))
print("MAD of ADT ctrl 0-1s:", median_abs_deviation(ADT1_Ctrl))
print ("Median of ADT ctrl 1-2s:", np.median(ADT2_Ctrl))
print("MAD of ADT ctrl 1-2s:", median_abs_deviation(ADT2_Ctrl))
print("Median of JUV ctrl 0-1s:", np.median(JUV1_Ctrl))
print("MAD of JUV ctrl 0-1s:", median_abs_deviation(JUV1_Ctrl))
print("Median of JUV ctrl 1-2s:", np.median(JUV2_Ctrl))
print("MAD of JUV ctrl 1-2s:", median_abs_deviation(JUV2_Ctrl))
        
x=np.array([1,2])
adtColor = (83/255,187/255,244/255)
juvColor = (255/255,67/255,46/255)
averageBoxPlot = StartPlots()
averageBoxPlot.ax.set_title('Decoding Accuracy and Control by Age Group, '+str((nIdx+1)*10)+' cells')
averageBoxPlot.ax.set_ylim([0.45,1])
boxplot = averageBoxPlot.ax.boxplot([ADT1, ADT2],
                                    positions= x - 0.3,widths=0.1,patch_artist=True, showfliers=False,
                                    boxprops=dict(facecolor=adtColor, edgecolor=adtColor),
                                    whiskerprops=dict(color=adtColor),
                                    capprops=dict(color=adtColor),
                                    medianprops=dict(marker='o', color='white', markersize=5))

boxplot =averageBoxPlot.ax.boxplot([ADT1_Ctrl,ADT2_Ctrl],
                                   positions=x - 0.1, widths=0.1,patch_artist=True, showfliers=False,
                                   boxprops=dict(facecolor=(0.7, 0.7, 0.7), edgecolor=(0.7, 0.7, 0.7)),
                                    whiskerprops=dict(color=(0.7, 0.7, 0.7)),
                                    capprops=dict(color=(0.7, 0.7, 0.7)),
                                    medianprops=dict(marker='o', color='white', markersize=5))

averageBoxPlot.ax.set_xticks(x, ['0-1s', '1-2s'])

# plot JUV
# plot data and ctrl
boxplot = averageBoxPlot.ax.boxplot([JUV1, JUV2],
                                    positions=x + 0.1,widths=0.1,patch_artist=True, showfliers=False,
                                    boxprops=dict(facecolor=juvColor, edgecolor=juvColor),
                                    whiskerprops=dict(color=juvColor),
                                    capprops=dict(color=juvColor),
                                    medianprops=dict(marker='o', color='white', markersize=5))

boxplot = averageBoxPlot.ax.boxplot([JUV1_Ctrl, JUV2_Ctrl],
                                    positions=x + 0.3,widths=0.1, patch_artist=True, showfliers=False,
                                    boxprops=dict(facecolor=(0.7, 0.7, 0.7), edgecolor=(0.7, 0.7, 0.7)),
                                    whiskerprops=dict(color=(0.7, 0.7, 0.7)),
                                    capprops=dict(color=(0.7, 0.7, 0.7)),
                                    medianprops=dict(marker='o', color='white', markersize=5)
                                    )

averageBoxPlot.ax.set_xticks([1, 2], ['0-1s', '1-2s'])
averageBoxPlot.ax.set_ylim([0.3, 1])
plt.show()
SummaryFolder = os.path.join(root_dir['LateLearnt'], r'Summary/ComparisonXLearning')
if not os.path.exists(SummaryFolder):
    os.makedirs(SummaryFolder)
averageBoxPlot.save_plot('Average decoding accuracy boxplot for nonlearners combined.png', 'png', SummaryFolder)
averageBoxPlot.save_plot('Average decoding accuracy boxplot for nonlearners combined.svg', 'svg', SummaryFolder)
# Out:
# Mannwhitney results between adults and adolescents in 0-1 and 1-2s time window:
# [0.83706294 0.75769231]
# Decoding accuracy for ADT 0-1s p-value: 6.5234e-01, adjusted p-value: 6.5234e-01
# Decoding accuracy for ADT 1-2s p-value: 4.2578e-01, adjusted p-value: 5.6771e-01
# Decoding accuracy for JUV 0-1s p-value: 1.5625e-02, adjusted p-value: 3.1250e-02
# Decoding accuracy for JUV 1-2s p-value: 1.5625e-02, adjusted p-value: 3.1250e-02
# Median of ADT 0-1s: 0.5996747967479674
# MAD of ADT 0-1s: 0.08605777547137161
# Median of ADT 1-2s: 0.6063233965672992
# MAD of ADT 1-2s: 0.05959137042350837
# Median of JUV 0-1s: 0.5593220338983051
# MAD of JUV 0-1s: 0.03092459800086922
# Median of JUV 1-2s: 0.6686055182699479
# MAD of JUV 1-2s: 0.03950498916941869
# Median of ADT ctrl 0-1s: 0.5369930069930069
# MAD of ADT ctrl 0-1s: 0.02139017011357436
# Median of ADT ctrl 1-2s: 0.5384615384615384
# MAD of ADT ctrl 1-2s: 0.022937503788567626
# Median of JUV ctrl 0-1s: 0.5344696969696969
# MAD of JUV ctrl 0-1s: 0.03549533799533794
# Median of JUV ctrl 1-2s: 0.5331649831649831
# MAD of JUV ctrl 1-2s: 0.03658378658378647
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 75
#      73 adtColor = (83/255,187/255,244/255)
#      74 juvColor = (255/255,67/255,46/255)
# ---> 75 averageBoxPlot = StartPlots()
#      76 averageBoxPlot.ax.set_title('Decoding Accuracy and Control by Age Group, '+str((nIdx+1)*10)+' cells')
#      77 averageBoxPlot.ax.set_ylim([0.45,1])
#
# NameError: name 'StartPlots' is not defined

# %%
# compare non-learners and learners
# Out:
# Decoding accuracy for ADT 0-1s p-value: 6.5234e-01, adjusted p-value: 6.5234e-01
# Decoding accuracy for ADT 1-2s p-value: 4.2578e-01, adjusted p-value: 5.6771e-01
# Decoding accuracy for JUV 0-1s p-value: 1.5625e-02, adjusted p-value: 3.1250e-02
# Decoding accuracy for JUV 1-2s p-value: 1.5625e-02, adjusted p-value: 3.1250e-02
#                         Mixed Linear Model Regression Results
# ======================================================================================
# Model:                       MixedLM            Dependent Variable:            resp
# No. Observations:            64                 Method:                        REML
# No. Groups:                  9                  Scale:                         0.0041
# Min. group size:             4                  Log-Likelihood:                49.4925
# Max. group size:             8                  Converged:                     No
# Mean group size:             7.1
# --------------------------------------------------------------------------------------
#                                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# --------------------------------------------------------------------------------------
# Intercept                                    0.623    0.041 15.064 0.000  0.542  0.704
# age[T.JUV]                                  -0.090    0.033 -2.768 0.006 -0.154 -0.026
# trial[T.Expt]                                0.012    0.031  0.370 0.712 -0.050  0.073
# time[T.2]                                    0.001    0.032  0.037 0.970 -0.061  0.064
# age[T.JUV]:trial[T.Expt]                     0.022    0.045  0.492 0.623 -0.066  0.110
# age[T.JUV]:time[T.2]                        -0.006    0.045 -0.140 0.888 -0.094  0.082
# trial[T.Expt]:time[T.2]                      0.012    0.045  0.264 0.792 -0.076  0.099
# age[T.JUV]:trial[T.Expt]:time[T.2]           0.053    0.062  0.849 0.396 -0.069  0.175
# Group Var                                    0.011    0.203
# Group x trial[T.Expt] Cov                   -0.000
# trial[T.Expt] Var                            0.001
# Group x time[T.2] Cov                        0.001
# trial[T.Expt] x time[T.2] Cov               -0.000
# time[T.2] Var                                0.001
# Group x trial[T.Expt]:time[T.2] Cov         -0.001
# trial[T.Expt] x trial[T.Expt]:time[T.2] Cov  0.001
# time[T.2] x trial[T.Expt]:time[T.2] Cov      0.001
# trial[T.Expt]:time[T.2] Var                  0.002
# ======================================================================================
#
# ADT Group ANOVA Results:
#                  Anova
# =======================================
#            F Value Num DF Den DF Pr > F
# ---------------------------------------
# trial       1.5787 1.0000 8.0000 0.2444
# time        5.3418 1.0000 8.0000 0.0496
# trial:time  1.7393 1.0000 8.0000 0.2237
# =======================================
#
# JUV Group ANOVA Results:
#                  Anova
# =======================================
#            F Value Num DF Den DF Pr > F
# ---------------------------------------
# trial      10.3680 1.0000 6.0000 0.0181
# time        4.0353 1.0000 6.0000 0.0913
# trial:time  4.1939 1.0000 6.0000 0.0865
# =======================================
#
# Comparison: Time 1 vs Time 2, Trial Ctrl vs Trial Expt
# T-statistic: -1.6171876564659222
# P-value: 0.14449951491741736

# %% [markdown]
# ## 2.3 Decoding of stimulus information
# - decode go or nogo stimulus from dF/F of all neurons
# - decode go or nogo stimulus from dF/F of 10:10:100 neurons (randomly sampled for 20 times and averaged across random samples)

# %%
n_predictors = 14
fluo_summary[key].decoding_session(n_predictors)
# Out:
#   0%|          | 0/71 [00:00<?, ?it/s]
# <fluorescent_pipeline.fluoAnalysis object at 0x0000020AEB033C70>
#   8%|▊         | 6/71 [00:00<00:04, 14.99it/s]
# <fluorescent_pipeline.fluoAnalysis object at 0x0000020AF196EC70>
# <fluorescent_pipeline.fluoAnalysis object at 0x0000020AF6F86B20>
#  11%|█▏        | 8/71 [00:01<00:11,  5.67it/s]
# <fluorescent_pipeline.fluoAnalysis object at 0x0000020AA81D8400>
#  13%|█▎        | 9/71 [00:01<00:15,  3.94it/s]
# <fluorescent_pipeline.fluoAnalysis object at 0x0000020AB30CECA0>
#  14%|█▍        | 10/71 [00:02<00:19,  3.11it/s]
# <fluorescent_pipeline.fluoAnalysis object at 0x0000020ABC300760>
#  15%|█▌        | 11/71 [00:02<00:21,  2.83it/s]
# <fluorescent_pipeline.fluoAnalysis object at 0x0000020AB3141D90>
#  17%|█▋        | 12/71 [00:03<00:20,  2.86it/s]
# <fluorescent_pipeline.fluoAnalysis object at 0x0000020BA646BB50>
#  35%|███▌      | 25/71 [00:03<00:03, 12.26it/s]
# <fluorescent_pipeline.fluoAnalysis object at 0x0000020BAE90C760>
#  38%|███▊      | 27/71 [00:03<00:04,  9.77it/s]
# <fluorescent_pipeline.fluoAnalysis object at 0x0000020BAEA4DCA0>
# <fluorescent_pipeline.fluoAnalysis object at 0x0000020BAF179CA0>
#  41%|████      | 29/71 [00:04<00:05,  8.30it/s]
# <fluorescent_pipeline.fluoAnalysis object at 0x0000020BEA56DAF0>
# <fluorescent_pipeline.fluoAnalysis object at 0x0000020C21396A30>
#  62%|██████▏   | 44/71 [00:04<00:01, 17.62it/s]
# <fluorescent_pipeline.fluoAnalysis object at 0x0000020C293B7670>
# <fluorescent_pipeline.fluoAnalysis object at 0x0000020C2D029CA0>
# <fluorescent_pipeline.fluoAnalysis object at 0x0000020C71251D00>
#  66%|██████▌   | 47/71 [00:05<00:02, 10.95it/s]
# <fluorescent_pipeline.fluoAnalysis object at 0x0000020C7133CC70>
# <fluorescent_pipeline.fluoAnalysis object at 0x0000020C720F7CD0>
#  69%|██████▉   | 49/71 [00:06<00:02,  8.10it/s]
# <fluorescent_pipeline.fluoAnalysis object at 0x0000020C76588CA0>
#  69%|██████▉   | 49/71 [00:06<00:02,  7.52it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 2
#       1 n_predictors = 14
# ----> 2 fluo_summary[key].decoding_session(n_predictors)
#
# File ~\Documents\GitHub\madeline_go_nogo\fluorescent_pipeline.py:4055, in fluoSum.decoding_session(self, n_predictors)
#    4052 else:
#    4053 # load the saved results
#    4054     with open(saveTbTFile, 'rb') as pf:
# -> 4055         tbtVar = pickle.load(pf)
#    4056         X = tbtVar['X']
#    4057         y = tbtVar['y']
#
# File ~\miniconda3\lib\site-packages\numpy\core\numeric.py:1869, in _frombuffer(buf, dtype, shape, order)
#    1861     return function(*args, **kwargs)
#    1864 _fromfunction_with_like = array_function_dispatch(
#    1865     _fromfunction_dispatcher
#    1866 )(fromfunction)
# -> 1869 def _frombuffer(buf, dtype, shape, order):
#    1870     return frombuffer(buf, dtype=dtype).reshape(shape, order=order)
#    1873 @set_module('numpy')
#    1874 def isscalar(element):
#
# KeyboardInterrupt:

# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2
from fluorescent_pipeline import *
fluo_summary[key].decoding_summary(ADT[key], JUV[key], group_label[key])
# Out:
# 100%|██████████| 12/12 [00:00<00:00, 12.56it/s]
# 100%|██████████| 28/28 [00:01<00:00, 16.55it/s]
#    nNeurons      p_MW  Adjusted p (FDR-bh)
# 0         0  0.023957             0.061723
# 1        10  0.043206             0.061723
# 2        20  0.043206             0.061723
# 3        30  0.072727             0.072727
# 4        40  0.032529             0.061723
# 5        50  0.054765             0.068193
# 6        60  0.061373             0.068193
# 7        70  0.014270             0.061723
# 8        80  0.030209             0.061723
# 9        90  0.004010             0.040100

# %% [markdown]
# ## 2.3 decode individual cue pairs (e.g. cue 5 against 6, and cue 3 against cue 4)

# %%
cue_list = [[3,4,5,6], [1,2,7,8],[1,3,6,8],[2,3,6,7],[1,4,5,8],[2,4,5,7]]
for cue_pairs in cue_list:
    fluo_summary.decoding_hardeasy_session(n_predictors, cue_pairs)
    fluo_summary.decoding_hardeasy_summary(ADT_late, JUV_late, cue_pairs, group_label)

# %% [markdown]
# ## 2.4 decoding accuracy of pseudo ensembles (shuffle the data to destroy the noise correlation)

# %%
fluo_summary.pseudo_session()
fluo_summary.pseudo_summray(ADT_late, JUV_late, group_label)

# %% [markdown]
# ## 2.5 noise correlation analysis (reference to be added)

# %%
fluo_summary.noise_session()
fluo_summary.noise_summary_Valente_2021(ADT_late, JUV_late, group_label)

# %% [markdown]
# ## to do: add cross learning stage comparisons
